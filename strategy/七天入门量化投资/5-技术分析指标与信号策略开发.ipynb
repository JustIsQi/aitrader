# %%
import talib
import pandas as pd
# %matplotlib inline

def get_data(symbol):
    data = pd.read_csv('data/{}.csv'.format(symbol))
    data['date'] = data['date'].apply(lambda x: str(x))
    data.set_index('date', inplace=True)
    data.sort_index(ascending=True, inplace=True)
    data.index = pd.to_datetime(data.index)
    data['openinterest'] = 0
    data = data[['open', 'high', 'low', 'close', 'volume', 'openinterest']]
    return data

symbol = '^NDX'
data = get_data(symbol)

# data = data[data.index>'20220101']
data
# Out:
#                     open          high           low         close  \
# date
# 1985-10-01    110.620003    112.160004    110.565002    112.139999
# 1985-10-02    112.139999    112.540001    110.779999    110.824997
# 1985-10-03    110.839996    111.184998    110.120003    110.870003
# 1985-10-04    110.870003    110.870003    109.855003    110.074997
# 1985-10-07    110.074997    110.135002    108.175003    108.199997
# ...                  ...           ...           ...           ...
# 2024-06-12  19358.259766  19556.900391  19347.279297  19465.179688
# 2024-06-13  19609.050781  19639.449219  19473.710938  19576.919922
# 2024-06-14  19557.220703  19664.589844  19534.619141  19659.800781
# 2024-06-17  19681.859375  19977.839844  19623.710938  19902.750000
# 2024-06-18  19904.429688  19940.500000  19837.859375  19908.859375
#
#                 volume  openinterest
# date
# 1985-10-01   153160000             0
# 1985-10-02   164640000             0
# 1985-10-03   147300000             0
# 1985-10-04   147900000             0
# 1985-10-07   128640000             0
# ...                ...           ...
# 2024-06-12  5560630000             0
# 2024-06-13  4916020000             0
# 2024-06-14  4973820000             0
# 2024-06-17  6061200000             0
# 2024-06-18  5796180000             0
#
# [9757 rows x 6 columns]

# %%
data['ma_20'] = talib.EMA(data['close'],20)
data['ma_5'] = talib.EMA(data['close'],5)
data
# Out:
#                     open          high           low         close  \
# date
# 1985-10-01    110.620003    112.160004    110.565002    112.139999
# 1985-10-02    112.139999    112.540001    110.779999    110.824997
# 1985-10-03    110.839996    111.184998    110.120003    110.870003
# 1985-10-04    110.870003    110.870003    109.855003    110.074997
# 1985-10-07    110.074997    110.135002    108.175003    108.199997
# ...                  ...           ...           ...           ...
# 2024-06-12  19358.259766  19556.900391  19347.279297  19465.179688
# 2024-06-13  19609.050781  19639.449219  19473.710938  19576.919922
# 2024-06-14  19557.220703  19664.589844  19534.619141  19659.800781
# 2024-06-17  19681.859375  19977.839844  19623.710938  19902.750000
# 2024-06-18  19904.429688  19940.500000  19837.859375  19908.859375
#
#                 volume  openinterest         ma_20          ma_5
# date
# 1985-10-01   153160000             0           NaN           NaN
# 1985-10-02   164640000             0           NaN           NaN
# 1985-10-03   147300000             0           NaN           NaN
# 1985-10-04   147900000             0           NaN           NaN
# 1985-10-07   128640000             0           NaN    110.421999
# ...                ...           ...           ...           ...
# 2024-06-12  5560630000             0  18782.511200  19183.500897
# 2024-06-13  4916020000             0  18858.169174  19314.640572
# 2024-06-14  4973820000             0  18934.515041  19429.693975
# 2024-06-17  6061200000             0  19026.727894  19587.379317
# 2024-06-18  5796180000             0  19110.740416  19694.539336
#
# [9757 rows x 8 columns]

# %%
data[['close','ma_20','ma_5']].plot()

# %%
data['macd'], data['signal'], _ = talib.MACD(data['close'], fastperiod=12, slowperiod=26, signalperiod=9)

# %%
data[['macd','signal']].plot()

# %%
data['upper_band'], data['middle_band'], data['lower_band'] = talib.BBANDS(data['close'], 
                                                      timeperiod=20, 
                                                      nbdevup=2, 
                                                      nbdevdn=2, 
                                                      matype=0)

# %%
data[['close','upper_band','lower_band']].plot()

# %%
atr = talib.ATR(data['high'], data['low'], data['close'], timeperiod=14)
atr
# Out:
# date
# 1985-10-01           NaN
# 1985-10-02           NaN
# 1985-10-03           NaN
# 1985-10-04           NaN
# 1985-10-07           NaN
#                  ...
# 2024-06-12    226.352043
# 2024-06-13    222.631863
# 2024-06-14    216.013209
# 2024-06-17    225.878616
# 2024-06-18    217.075902
# Length: 9757, dtype: float64

# %%
atr.plot()

# %%
data
# Out:
#                     open          high           low         close  \
# date
# 1985-10-01    110.620003    112.160004    110.565002    112.139999
# 1985-10-02    112.139999    112.540001    110.779999    110.824997
# 1985-10-03    110.839996    111.184998    110.120003    110.870003
# 1985-10-04    110.870003    110.870003    109.855003    110.074997
# 1985-10-07    110.074997    110.135002    108.175003    108.199997
# ...                  ...           ...           ...           ...
# 2024-06-12  19358.259766  19556.900391  19347.279297  19465.179688
# 2024-06-13  19609.050781  19639.449219  19473.710938  19576.919922
# 2024-06-14  19557.220703  19664.589844  19534.619141  19659.800781
# 2024-06-17  19681.859375  19977.839844  19623.710938  19902.750000
# 2024-06-18  19904.429688  19940.500000  19837.859375  19908.859375
#
#                 volume  openinterest         ma_20          ma_5        macd  \
# date
# 1985-10-01   153160000             0           NaN           NaN         NaN
# 1985-10-02   164640000             0           NaN           NaN         NaN
# 1985-10-03   147300000             0           NaN           NaN         NaN
# 1985-10-04   147900000             0           NaN           NaN         NaN
# 1985-10-07   128640000             0           NaN    110.421999         NaN
# ...                ...           ...           ...           ...         ...
# 2024-06-12  5560630000             0  18782.511200  19183.500897  283.609558
# 2024-06-13  4916020000             0  18858.169174  19314.640572  311.822789
# 2024-06-14  4973820000             0  18934.515041  19429.693975  336.985215
# 2024-06-17  6061200000             0  19026.727894  19587.379317  372.239643
# 2024-06-18  5796180000             0  19110.740416  19694.539336  396.105944
#
#                 signal    upper_band   middle_band    lower_band
# date
# 1985-10-01         NaN           NaN           NaN           NaN
# 1985-10-02         NaN           NaN           NaN           NaN
# 1985-10-03         NaN           NaN           NaN           NaN
# 1985-10-04         NaN           NaN           NaN           NaN
# 1985-10-07         NaN           NaN           NaN           NaN
# ...                ...           ...           ...           ...
# 2024-06-12  239.269527  19301.637782  18798.515039  18295.392296
# 2024-06-13  253.780179  19444.651766  18847.528516  18250.405265
# 2024-06-14  270.421186  19580.560797  18902.620508  18224.680218
# 2024-06-17  290.784878  19755.207984  18970.446484  18185.684984
# 2024-06-18  311.849091  19903.487400  19032.179980  18160.872561
#
# [9757 rows x 13 columns]

# %%
import bt
import numpy as np

close = data[['close']]
upper = data[['upper_band']]
lower = data[['lower_band']]
close.columns=[symbol]
upper.columns=[symbol]
lower.columns=[symbol]

buy = close > upper
sell = close < lower

signal_where = np.where(buy,1,np.nan)
signal_where = np.where(sell,0,signal_where)
signal_where = pd.DataFrame(signal_where,index=close.index,columns=close.columns)
signal_where = signal_where.ffill()
signal_where = signal_where.fillna(0)
signal_where

# create the strategy
s = bt.Strategy('s1', [bt.algos.RunMonthly(),
                       bt.algos.SelectWhere(signal_where),
                       bt.algos.WeighEqually(),
                       bt.algos.Rebalance()])

# %%
# create a backtest and run it
test = bt.Backtest(s, close)
res = bt.run(test)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.29s/it]

# %%
res.plot()

# %%
res.stats
# Out:
#                                         s1
# start                  1985-09-30 00:00:00
# end                    2024-06-18 00:00:00
# rf                                     0.0
# total_return                     19.730485
# cagr                              0.081451
# max_drawdown                      -0.55299
# calmar                            0.147292
# mtd                               0.070293
# three_month                       0.030646
# six_month                         0.107945
# ytd                               0.101618
# one_year                          0.189895
# three_year                        0.070843
# five_year                         0.133237
# ten_year                          0.064711
# incep                             0.081451
# daily_sharpe                      0.541915
# daily_sortino                     0.816119
# daily_mean                        0.093132
# daily_vol                         0.171857
# daily_skew                       -0.423911
# daily_kurt                       14.311847
# best_day                          0.102929
# worst_day                        -0.150758
# monthly_sharpe                    0.553204
# monthly_sortino                   0.959017
# monthly_mean                      0.092521
# monthly_vol                       0.167245
# monthly_skew                     -0.028279
# monthly_kurt                      7.320074
# best_month                        0.249785
# worst_month                      -0.269721
# yearly_sharpe                     0.485094
# yearly_sortino                    1.782198
# yearly_mean                       0.094619
# yearly_vol                        0.195052
# yearly_skew                       1.297447
# yearly_kurt                       2.383435
# best_year                         0.761496
# worst_year                       -0.202767
# avg_drawdown                     -0.042249
# avg_drawdown_days                85.379747
# avg_up_month                      0.041456
# avg_down_month                   -0.018209
# win_year_perc                      0.74359
# twelve_month_win_perc             0.679121

# %%
res.get_transactions()
# Out:
#                              price  quantity
# Date       Security
# 1985-12-02 000300.SH    125.184998    7988.0
# 1986-02-03 000300.SH    134.240005   -7988.0
# 1986-03-03 000300.SH    139.740005    7673.0
# 1986-08-01 000300.SH    144.190002   -7673.0
# 1986-11-03 000300.SH    144.809998    7640.0
# ...                            ...       ...
# 2023-02-01 000300.SH  12363.099609    1155.0
# 2023-09-01 000300.SH  15490.860352   -1155.0
# 2023-12-01 000300.SH  15997.580078    1118.0
# 2024-05-01 000300.SH  17318.550781   -1118.0
# 2024-06-03 000300.SH  18600.970703    1041.0
#
# [168 rows x 2 columns]
